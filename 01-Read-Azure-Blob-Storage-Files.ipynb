# %% [markdown]
# ##Instalar pacote Azure Blob Storage

# %%
pip install azure-storage-blob
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Python interpreter will be restarted.
# Collecting azure-storage-blob
#   Using cached azure_storage_blob-12.13.1-py3-none-any.whl (377 kB)
# Collecting msrest&gt;=0.6.21
#   Using cached msrest-0.7.1-py3-none-any.whl (85 kB)
# Collecting azure-core&lt;2.0.0,&gt;=1.23.1
#   Using cached azure_core-1.25.1-py3-none-any.whl (178 kB)
# Collecting cryptography&gt;=2.1.4
#   Using cached cryptography-38.0.1-cp36-abi3-manylinux_2_28_x86_64.whl (4.2 MB)
# Requirement already satisfied: requests&gt;=2.18.4 in /databricks/python3/lib/python3.8/site-packages (from azure-core&lt;2.0.0,&gt;=1.23.1-&gt;azure-storage-blob) (2.25.1)
# Collecting typing-extensions&gt;=4.0.1
#   Using cached typing_extensions-4.3.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: six&gt;=1.11.0 in /databricks/python3/lib/python3.8/site-packages (from azure-core&lt;2.0.0,&gt;=1.23.1-&gt;azure-storage-blob) (1.15.0)
# Requirement already satisfied: cffi&gt;=1.12 in /databricks/python3/lib/python3.8/site-packages (from cryptography&gt;=2.1.4-&gt;azure-storage-blob) (1.14.5)
# Requirement already satisfied: pycparser in /databricks/python3/lib/python3.8/site-packages (from cffi&gt;=1.12-&gt;cryptography&gt;=2.1.4-&gt;azure-storage-blob) (2.20)
# Collecting isodate&gt;=0.6.0
#   Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Requirement already satisfied: certifi&gt;=2017.4.17 in /databricks/python3/lib/python3.8/site-packages (from msrest&gt;=0.6.21-&gt;azure-storage-blob) (2020.12.5)
# Collecting requests-oauthlib&gt;=0.5.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: urllib3&lt;1.27,&gt;=1.21.1 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.18.4-&gt;azure-core&lt;2.0.0,&gt;=1.23.1-&gt;azure-storage-blob) (1.25.11)
# Requirement already satisfied: idna&lt;3,&gt;=2.5 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.18.4-&gt;azure-core&lt;2.0.0,&gt;=1.23.1-&gt;azure-storage-blob) (2.10)
# Requirement already satisfied: chardet&lt;5,&gt;=3.0.2 in /databricks/python3/lib/python3.8/site-packages (from requests&gt;=2.18.4-&gt;azure-core&lt;2.0.0,&gt;=1.23.1-&gt;azure-storage-blob) (4.0.0)
# Collecting oauthlib&gt;=3.0.0
#   Using cached oauthlib-3.2.1-py3-none-any.whl (151 kB)
# Installing collected packages: typing-extensions, oauthlib, requests-oauthlib, isodate, azure-core, msrest, cryptography, azure-storage-blob
# Successfully installed azure-core-1.25.1 azure-storage-blob-12.13.1 cryptography-38.0.1 isodate-0.6.1 msrest-0.7.1 oauthlib-3.2.1 requests-oauthlib-1.3.1 typing-extensions-4.3.0
# Python interpreter will be restarted.
# </div>

# %% [markdown]
# ##Acessar o Recurso Azure Blob Storage

# %%
from azure.storage.blob import BlobServiceClient
import pandas as pd 

storage_account_name = 'fabiomsdatalake'
storage_account_access_key = 'umJaI6/+FQYSYfW0bqY54ov0nS1ZGxB+WpobLePKpvxpcHXZL9jIsh7soowClEzcTCxa29TfeOTE+AStkN8p+w=='
spark.conf.set('fs.azure.account.key.' + storage_account_name + '.blob.core.windows.net', storage_account_access_key)
blob_container = 'fabiomsfilesys'
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##Ler os arquivos em formato CSV

# %%
file2018 = 'wasbs://' + blob_container + '@' + storage_account_name + '.blob.core.windows.net/SUP_IES_2018.CSV'
file2019 = 'wasbs://' + blob_container + '@' + storage_account_name + '.blob.core.windows.net/SUP_IES_2019.CSV'

sup_ies_2018 = spark.read.format('csv').load(file2018, inferSchema = True, header = True, delimiter = '|', encoding = 'cp1252')
sup_ies_2019 = spark.read.format('csv').load(file2019, inferSchema = True, header = True, delimiter = '|', encoding = 'cp1252')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##Converter Spark Dataframe para Pandas

# %%
df_2018 = sup_ies_2018.toPandas()
df_2019 = sup_ies_2019.toPandas()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##Visualizar as colunas e os tipos de dados

# %%
df_2018.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 2537 entries, 0 to 2536
# Data columns (total 48 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   NU_ANO_CENSO                    2537 non-null   int32
#  1   CO_IES                          2537 non-null   int32
#  2   NO_IES                          2537 non-null   object
#  3   SG_IES                          2111 non-null   object
#  4   CO_MANTENEDORA                  2537 non-null   int32
#  5   NO_MANTENEDORA                  2537 non-null   object
#  6   TP_CATEGORIA_ADMINISTRATIVA     2537 non-null   int32
#  7   TP_ORGANIZACAO_ACADEMICA        2537 non-null   int32
#  8   CO_REGIAO                       2537 non-null   int32
#  9   CO_UF                           2537 non-null   int32
#  10  CO_MUNICIPIO                    2537 non-null   int32
#  11  IN_CAPITAL                      2537 non-null   int32
#  12  QT_TEC_TOTAL                    2537 non-null   int32
#  13  QT_TEC_FUNDAMENTAL_INCOMP_FEM   2537 non-null   int32
#  14  QT_TEC_FUNDAMENTAL_INCOMP_MASC  2537 non-null   int32
#  15  QT_TEC_FUNDAMENTAL_COMP_FEM     2537 non-null   int32
#  16  QT_TEC_FUNDAMENTAL_COMP_MASC    2537 non-null   int32
#  17  QT_TEC_MEDIO_FEM                2537 non-null   int32
#  18  QT_TEC_MEDIO_MASC               2537 non-null   int32
#  19  QT_TEC_SUPERIOR_FEM             2537 non-null   int32
#  20  QT_TEC_SUPERIOR_MASC            2537 non-null   int32
#  21  QT_TEC_ESPECIALIZACAO_FEM       2537 non-null   int32
#  22  QT_TEC_ESPECIALIZACAO_MASC      2537 non-null   int32
#  23  QT_TEC_MESTRADO_FEM             2537 non-null   int32
#  24  QT_TEC_MESTRADO_MASC            2537 non-null   int32
#  25  QT_TEC_DOUTORADO_FEM            2537 non-null   int32
#  26  QT_TEC_DOUTORADO_MASC           2537 non-null   int32
#  27  IN_ACESSO_PORTAL_CAPES          2537 non-null   int32
#  28  IN_ACESSO_OUTRAS_BASES          0 non-null      object
#  29  IN_ASSINA_OUTRA_BASE            2537 non-null   int32
#  30  IN_REPOSITORIO_INSTITUCIONAL    2537 non-null   int32
#  31  IN_BUSCA_INTEGRADA              2537 non-null   int32
#  32  IN_SERVICO_INTERNET             2537 non-null   int32
#  33  IN_PARTICIPA_REDE_SOCIAL        2537 non-null   int32
#  34  IN_CATALOGO_ONLINE              2537 non-null   int32
#  35  QT_PERIODICO_ELETRONICO         2537 non-null   int32
#  36  QT_LIVRO_ELETRONICO             2537 non-null   int32
#  37  TP_REFERENTE                    2537 non-null   int32
#  38  VL_RECEITA_PROPRIA              2537 non-null   float64
#  39  VL_RECEITA_TRANSFERENCIA        2537 non-null   float64
#  40  VL_RECEITA_OUTRA                2537 non-null   float64
#  41  VL_DESPESA_PESSOAL_DOCENTE      2537 non-null   float64
#  42  VL_DESPESA_PESSOAL_TECNICO      2537 non-null   float64
#  43  VL_DESPESA_PESSOAL_ENCARGO      2537 non-null   float64
#  44  VL_DESPESA_CUSTEIO              2537 non-null   float64
#  45  VL_DESPESA_INVESTIMENTO         2537 non-null   float64
#  46  VL_DESPESA_PESQUISA             2537 non-null   float64
#  47  VL_DESPESA_OUTRA                2537 non-null   float64
# dtypes: float64(10), int32(34), object(4)
# memory usage: 614.6+ KB
# </div>

# %%
df_2019.info()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 2608 entries, 0 to 2607
# Data columns (total 48 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   NU_ANO_CENSO                    2608 non-null   int32
#  1   CO_IES                          2608 non-null   int32
#  2   NO_IES                          2608 non-null   object
#  3   SG_IES                          2144 non-null   object
#  4   CO_MANTENEDORA                  2608 non-null   int32
#  5   NO_MANTENEDORA                  2608 non-null   object
#  6   TP_CATEGORIA_ADMINISTRATIVA     2608 non-null   int32
#  7   TP_ORGANIZACAO_ACADEMICA        2608 non-null   int32
#  8   CO_REGIAO                       2608 non-null   int32
#  9   CO_UF                           2608 non-null   int32
#  10  CO_MUNICIPIO                    2608 non-null   int32
#  11  IN_CAPITAL                      2608 non-null   int32
#  12  QT_TEC_TOTAL                    2608 non-null   int32
#  13  QT_TEC_FUNDAMENTAL_INCOMP_FEM   2608 non-null   int32
#  14  QT_TEC_FUNDAMENTAL_INCOMP_MASC  2608 non-null   int32
#  15  QT_TEC_FUNDAMENTAL_COMP_FEM     2608 non-null   int32
#  16  QT_TEC_FUNDAMENTAL_COMP_MASC    2608 non-null   int32
#  17  QT_TEC_MEDIO_FEM                2608 non-null   int32
#  18  QT_TEC_MEDIO_MASC               2608 non-null   int32
#  19  QT_TEC_SUPERIOR_FEM             2608 non-null   int32
#  20  QT_TEC_SUPERIOR_MASC            2608 non-null   int32
#  21  QT_TEC_ESPECIALIZACAO_FEM       2608 non-null   int32
#  22  QT_TEC_ESPECIALIZACAO_MASC      2608 non-null   int32
#  23  QT_TEC_MESTRADO_FEM             2608 non-null   int32
#  24  QT_TEC_MESTRADO_MASC            2608 non-null   int32
#  25  QT_TEC_DOUTORADO_FEM            2608 non-null   int32
#  26  QT_TEC_DOUTORADO_MASC           2608 non-null   int32
#  27  IN_ACESSO_PORTAL_CAPES          2608 non-null   int32
#  28  IN_ACESSO_OUTRAS_BASES          0 non-null      object
#  29  IN_ASSINA_OUTRA_BASE            2608 non-null   int32
#  30  IN_REPOSITORIO_INSTITUCIONAL    2608 non-null   int32
#  31  IN_BUSCA_INTEGRADA              2608 non-null   int32
#  32  IN_SERVICO_INTERNET             2608 non-null   int32
#  33  IN_PARTICIPA_REDE_SOCIAL        2608 non-null   int32
#  34  IN_CATALOGO_ONLINE              2608 non-null   int32
#  35  QT_PERIODICO_ELETRONICO         2608 non-null   int32
#  36  QT_LIVRO_ELETRONICO             2608 non-null   int32
#  37  TP_REFERENTE                    2608 non-null   int32
#  38  VL_RECEITA_PROPRIA              2608 non-null   float64
#  39  VL_RECEITA_TRANSFERENCIA        2608 non-null   float64
#  40  VL_RECEITA_OUTRA                2608 non-null   float64
#  41  VL_DESPESA_PESSOAL_DOCENTE      2608 non-null   float64
#  42  VL_DESPESA_PESSOAL_TECNICO      2608 non-null   float64
#  43  VL_DESPESA_PESSOAL_ENCARGO      2608 non-null   float64
#  44  VL_DESPESA_CUSTEIO              2608 non-null   float64
#  45  VL_DESPESA_INVESTIMENTO         2608 non-null   float64
#  46  VL_DESPESA_PESQUISA             2608 non-null   float64
#  47  VL_DESPESA_OUTRA                2608 non-null   float64
# dtypes: float64(10), int32(34), object(4)
# memory usage: 631.8+ KB
# </div>

# %% [markdown]
# ##Combinar os registros

# %%
df = df_2018.append([df_2019])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ##Visualizar os registros combinados

# %%
df.groupby('NU_ANO_CENSO')['NU_ANO_CENSO'].count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: NU_ANO_CENSO
# 2018    2537
# 2019    2608
# Name: NU_ANO_CENSO, dtype: int64</div>

# %%
df.groupby('NU_ANO_CENSO')['QT_TEC_TOTAL'].mean()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]